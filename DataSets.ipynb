# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaSaiRamu/Data-Analytics-/blob/main/DataSets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('food.csv')

# %%
df.head()
# Out:
#      order_id customer_id restaurant_id driver_id      order_timestamp  \
# 0  ORD_000001   CUS_00001      RES_0008  DRV_0075  2025-10-05 15:54:00
# 1  ORD_000002   CUS_00013      RES_0024  DRV_0131  2025-10-01 20:00:00
# 2  ORD_000003   CUS_00049      RES_0013  DRV_0087  2025-10-07 18:24:00
# 3  ORD_000004   CUS_00007      RES_0001  DRV_0177  2025-10-30 16:54:00
# 4  ORD_000005   CUS_00325      RES_0029  DRV_0114  2025-10-15 18:34:00
#
#    order_date  order_hour day_of_week  is_weekend    city  ... traffic_level  \
# 0  2025-10-05          15      Sunday           1  City_C  ...        Medium
# 1  2025-10-01          20   Wednesday           0  City_A  ...          High
# 2  2025-10-07          18     Tuesday           0  City_C  ...          High
# 3  2025-10-30          16    Thursday           0  City_A  ...           Low
# 4  2025-10-15          18   Wednesday           0  City_B  ...        Medium
#
#    delivery_partner_experience_months delivery_partner_rating  \
# ...

# %%
df.sample(1)
# Out:
#          order_id customer_id restaurant_id driver_id      order_timestamp  \
# 32380  ORD_032381   CUS_00154      RES_0115  DRV_0145  2025-10-02 12:00:00
#
#        order_date  order_hour day_of_week  is_weekend    city  ...  \
# 32380  2025-10-02          12    Thursday           0  City_B  ...
#
#       traffic_level  delivery_partner_experience_months  \
# 32380          High                                  12
#
#       delivery_partner_rating restaurant_preparation_time_minutes  \
# 32380                     4.6                                  19
#
#       estimated_delivery_time_minutes  actual_delivery_time_minutes  \
# 32380                              84                          90.0
#
#        late_delivery  order_status  cancellation_reason  customer_rating
# 32380            1.0     Completed                  NaN              4.0
#
# [1 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 37 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   order_id                             50000 non-null  object
#  1   customer_id                          50000 non-null  object
#  2   restaurant_id                        50000 non-null  object
#  3   driver_id                            50000 non-null  object
#  4   order_timestamp                      50000 non-null  object
#  5   order_date                           50000 non-null  object
#  6   order_hour                           50000 non-null  int64
#  7   day_of_week                          50000 non-null  object
#  8   is_weekend                           50000 non-null  int64
#  9   city                                 50000 non-null  object
#  10  delivery_area                        50000 non-null  object
# ...

# %%
df.sample(5)
# Out:
#          order_id customer_id restaurant_id driver_id      order_timestamp  \
# 7584   ORD_007585   CUS_00047      RES_0152  DRV_0146  2025-10-30 12:26:00
# 28714  ORD_028715   CUS_00217      RES_0027  DRV_0144  2025-10-30 00:32:00
# 20868  ORD_020869   CUS_00002      RES_0003  DRV_0019  2025-10-10 11:57:00
# 11379  ORD_011380   CUS_00005      RES_0090  DRV_0130  2025-10-06 02:09:00
# 42005  ORD_042006   CUS_00065      RES_0018  DRV_0133  2025-10-09 20:42:00
#
#        order_date  order_hour day_of_week  is_weekend    city  ...  \
# 7584   2025-10-30          12    Thursday           0  City_A  ...
# 28714  2025-10-30           0    Thursday           0  City_A  ...
# 20868  2025-10-10          11      Friday           0  City_C  ...
# 11379  2025-10-06           2      Monday           0  City_B  ...
# 42005  2025-10-09          20    Thursday           0  City_B  ...
#
#       traffic_level  delivery_partner_experience_months  \
# ...

# %%
df.describe()
# Out:
#          order_hour   is_weekend  customer_age  restaurant_rating  \
# count  50000.000000  50000.00000  50000.000000       50000.000000
# mean      14.465900      0.26712     27.686580           4.207956
# std        5.231155      0.44246      7.537796           0.450977
# min        0.000000      0.00000     18.000000           2.800000
# 25%       11.000000      0.00000     21.000000           3.900000
# 50%       14.000000      0.00000     27.000000           4.200000
# 75%       19.000000      1.00000     33.000000           4.600000
# max       23.000000      1.00000     55.000000           5.000000
#
#        items_count      subtotal  discount_percent    tax_amount  \
# count  50000.00000  50000.000000      50000.000000  50000.000000
# mean       2.91002     30.897938          4.495700      4.128796
# std        2.02907     27.068965          6.430008      3.636275
# min        1.00000      5.100000          0.000000      0.570000
# ...

# %%
df.set_index('order_id')
# Out:
#            customer_id restaurant_id driver_id      order_timestamp  \
# order_id
# ORD_000001   CUS_00001      RES_0008  DRV_0075  2025-10-05 15:54:00
# ORD_000002   CUS_00013      RES_0024  DRV_0131  2025-10-01 20:00:00
# ORD_000003   CUS_00049      RES_0013  DRV_0087  2025-10-07 18:24:00
# ORD_000004   CUS_00007      RES_0001  DRV_0177  2025-10-30 16:54:00
# ORD_000005   CUS_00325      RES_0029  DRV_0114  2025-10-15 18:34:00
# ...                ...           ...       ...                  ...
# ORD_049996   CUS_00280      RES_0130  DRV_0112  2025-10-25 12:16:00
# ORD_049997   CUS_00893      RES_0028  DRV_0036  2025-10-05 19:48:00
# ORD_049998   CUS_01618      RES_0001  DRV_0071  2025-10-08 12:18:00
# ORD_049999   CUS_00025      RES_0057  DRV_0103  2025-10-20 17:39:00
# ORD_050000   CUS_00038      RES_0139  DRV_0131  2025-10-13 17:36:00
#
#             order_date  order_hour day_of_week  is_weekend    city  \
# order_id
# ...

# %%
df.head()
# Out:
#      order_id customer_id restaurant_id driver_id      order_timestamp  \
# 0  ORD_000001   CUS_00001      RES_0008  DRV_0075  2025-10-05 15:54:00
# 1  ORD_000002   CUS_00013      RES_0024  DRV_0131  2025-10-01 20:00:00
# 2  ORD_000003   CUS_00049      RES_0013  DRV_0087  2025-10-07 18:24:00
# 3  ORD_000004   CUS_00007      RES_0001  DRV_0177  2025-10-30 16:54:00
# 4  ORD_000005   CUS_00325      RES_0029  DRV_0114  2025-10-15 18:34:00
#
#    order_date  order_hour day_of_week  is_weekend    city  ... traffic_level  \
# 0  2025-10-05          15      Sunday           1  City_C  ...        Medium
# 1  2025-10-01          20   Wednesday           0  City_A  ...          High
# 2  2025-10-07          18     Tuesday           0  City_C  ...          High
# 3  2025-10-30          16    Thursday           0  City_A  ...           Low
# 4  2025-10-15          18   Wednesday           0  City_B  ...        Medium
#
#    delivery_partner_experience_months delivery_partner_rating  \
# ...
